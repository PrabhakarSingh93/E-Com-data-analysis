# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#         You have been given the role of a business analyst for an E-Commerce company and have been asked to prepare a basic report on the data. Follow the steps below for preparation of the report.
#
# Before you start analysing the data, it is always a good practice to see the size of the data, its features and feature types. If the data set is big, it is not possible to print out all the records.
#     </font>
# ####  Note: Use the markdown feature of Python to explain your answer.

# %% [markdown]
# ## Load the necessary libraries. Import and load the dataset with a name ECom_Data .

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
pd.options.display.max_rows = 10

# %%
# Get the Data

ECom_Data=pd.read_csv("E-Commerce.csv")

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#         We have read the data and stored the data in "ECom_Data" variable </font>

# %% [markdown]
# ## Q 1.	To get familiar with the data
# ## a)	Print out the first 10 and the last 10 records of the data. (2 marks)
# ## b)	How many rows and columns are present in the dataset? Use any two different methods to extract this information. (2 + 2 + 2 marks)
# ## c)	How many object data types are there? (1 mark)
# ## d)	Is there any Boolean data type? (1 mark)
# #### Note: Use the markdown feature of Python to explain your answer.

# %% [markdown]
# #### Ans 1 a)

# %% [markdown]
# #### First 10 rows in the dataset are following:

# %%
ECom_Data.head(10)
# Out:
#                    Customer_uniq_id Region  Order_Date Expected_Delivery_Date
# 0  e71017e224688489edfe856f2308806d  East   24-10-2021             25-10-2021  \
# 1  6286847ee2da18f587503db49511c539  East   24-10-2021             25-10-2021
# 2  0686fec9b70e5039583a38119ca0c835   West  24-10-2021             25-10-2021
# 3  ea2406dc597bee2abb6b867fa668501f   West  24-10-2021             25-10-2021
# 4  5935ed077915347dc695744df68c565c  East   03-09-2021             04-09-2021
# 5  89fcdddaad50084e395d0928a7426afe  East   03-09-2021             04-09-2021
# 6  b9b183aa18d3a721d2ac23e7184525b0  East   03-09-2021             04-09-2021
# 7  dee64864c0419bec80fbbb94d19bc40d  East   03-09-2021             04-09-2021
# 8  595f55f2c1293f07ea9ec9fa2bb39f46  East   03-09-2021             04-09-2021
# 9  547b6585272473ae006bcfbdb47b6ae0   West  26-08-2021             27-08-2021
#
#   Delivered_Date                                       product_name
# ...

# %% [markdown]
# #### Last 10 rows in the dataset are following:

# %%
ECom_Data.tail(10)
# Out:
#                       Customer_uniq_id Region  Order_Date
# 8896  4db03bc4ccbe216cf151b2f2b904ba3f  East   01-12-2020  \
# 8897  4d4d6aeb13fa253499d0dd45a5abd87e   West  01-12-2020
# 8898  ea19e7ef703293d3f6c799ca9db4642d   West  01-12-2020
# 8899  19a53a958992fb575acffb5d41e7ef9e  East   01-12-2020
# 8900  09abab80c8dfdc6f268e0a6f05a0be11  North  01-12-2020
# 8901  90d30478255e23621e8929ed15c2f6e4  South  01-12-2020
# 8902  20a73e3f41490a73ceeba5f17658db8f   West  01-12-2020
# 8903  5c1554cd45f9d538c2c6947dbdd59c75  East   01-12-2020
# 8904  6b737a4deca1ed0e56c179e66036e994   West  01-12-2020
# 8905  a5235ac28d3d5487f54025f9d6b57433  North  01-12-2020
#
#      Expected_Delivery_Date Delivered_Date
# 8896             04-12-2020     04-12-2020  \
# 8897             04-12-2020     04-12-2020
# 8898             04-12-2020     04-12-2020
# 8899             04-12-2020     04-12-2020
# 8900             04-12-2020     04-12-2020
# 8901             04-12-2020     04-12-2020
# ...

# %% [markdown]
# #### Ans 1 b)

# %%
## 1st Method to find rows and columns 

ECom_Data.shape
# Out:
# (8906, 17)

# %%
print("The number of rows present are",ECom_Data.shape[0],"and the number of columns present are",ECom_Data.shape[1],"in given dataset")
# Out:
# The number of rows present are 8906 and the number of columns present are 17 in given dataset

# %%
## 2nd Method to find rows and columns 

rows=len(ECom_Data.index)
columns=len(ECom_Data.columns)

# %%
print("The number of rows present are",rows,"and the number of columns present are",columns,"in given dataset")
# Out:
# The number of rows present are 8906 and the number of columns present are 17 in given dataset

# %% [markdown]
# #### Ans  1 c)

# %%
ECom_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8906 entries, 0 to 8905
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Customer_uniq_id            8906 non-null   object
#  1   Region                      8906 non-null   object
#  2   Order_Date                  8906 non-null   object
#  3   Expected_Delivery_Date      8906 non-null   object
#  4   Delivered_Date              8906 non-null   object
#  5   product_name                8906 non-null   object
#  6   product_main_category       8906 non-null   object
#  7   product_subcategory         8906 non-null   object
#  8   product_category_filter     8906 non-null   object
#  9   product_category_subfilter  8906 non-null   object
#  10  product_unique ID           8906 non-null   object
#  11  retail_price                8906 non-null   int64
#  12  discounted_price            8906 non-null   int64
# ...

# %% [markdown]
# #### As we can see that there are 14 columns of object data types in given datasets

# %% [markdown]
# ### Ans 1 d)

# %% [markdown]
# #### As we can see there are no boolean type data present in the datasets.

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#  Once you are familiar with the data, you may decide that not all features are of use to you and you may want to delete the non-informative features (columns)</font>

# %% [markdown]
# ## Q 2.	Eliminating the non-informative columns.
# ## a)	Drop the columns product_specifications and description. (2 marks)
# ## b)	Which method or function is used to permanently delete the columns mentioned in part (a)? Write the code explicitly (2 marks)
# ### Note: Use the markdown feature of Python to explain your answer.

# %% [markdown]
# ### Ans 2 a)

# %%
### Here is the code to drop columns 

ECom_Data.drop(["product_specifications","description"],axis=1,inplace=True)

# %%
ECom_Data.head()
# Out:
#                    Customer_uniq_id Region  Order_Date Expected_Delivery_Date
# 0  e71017e224688489edfe856f2308806d  East   24-10-2021             25-10-2021  \
# 1  6286847ee2da18f587503db49511c539  East   24-10-2021             25-10-2021
# 2  0686fec9b70e5039583a38119ca0c835   West  24-10-2021             25-10-2021
# 3  ea2406dc597bee2abb6b867fa668501f   West  24-10-2021             25-10-2021
# 4  5935ed077915347dc695744df68c565c  East   03-09-2021             04-09-2021
#
#   Delivered_Date                                       product_name
# 0     25-10-2021  Indcrown Net Embroidered Semi-stitched Lehenga...  \
# 1     25-10-2021      Shopmania Music Band A5 Notebook Spiral Bound
# 2     25-10-2021      Shopmania Music Band A5 Notebook Spiral Bound
# 3     25-10-2021  Tiara Diaries 2016-2017 Designer LA Kaarta "TA...
# 4     04-09-2021                KAJCI Embroidered Women's Waistcoat
#
#   product_main_category    product_subcategory product_category_filter
# ...

# %% [markdown]
# ### Ans 2 b)

# %% [markdown]
# #### Code used for drop columns in Ques (a) is  ECom_Data.drop(["product_specifications","description"],axis=1,inplace=True)
# #### Here .drop() is used to drop columns and to make it permanent we use "inplace=True" and axis=1 is to indicate that we want
# #### to delete columns. Similarly axis=0 is used for rows.

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#         The next steps in this project involves summarization of data at various levels and visualization. Apparently, such simple steps are very useful to get an overall sense of the data.
#     </font>

# %% [markdown]
# ## Q 3. Here we summarize the data at Brand level.
# ## a) How many unique Brand are there? (2 marks)
# ## b) Note that each Brand contains multiple products. Show the average product_rating within each Brand (2 marks)

# %% [markdown]
# ### Ans 3 a)

# %%
ECom_Data["Brand"].unique()
# Out:
# array(['INDCROWN', 'SHOPMANIA', 'TIARA DIARIES', ..., 'SININA',
#        'AARUSHI FASHION', 'AMBIKA LAHENGA'], dtype=object)

# %%
ECom_Data["Brand"].nunique()
# Out:
# 2484

# %% [markdown]
# #### .unique() is used to get list of unique items and .nunique() counts number of unique items. So in the given datasets we have 2484 unique brands.

# %% [markdown]
# ### Ans 3 b)

# %%
## Here is the code for getting average rating of brand based on different products in decreasing order

pd.DataFrame(ECom_Data.groupby(["Brand"])["product_rating"].mean().sort_values(ascending=False))
# Out:
#                         product_rating
# Brand
#  TARKAN                            5.0
# INDIANO                            5.0
# PUMPKIN PATCH                      5.0
# PURE SOURCE                        5.0
# BRAHAAN BLUE TAG                   5.0
# ...                                ...
# BRIGHT HOME APPLIANCES             1.0
# TWIN TWINE                         1.0
# BRECKEN PAUL                       1.0
# QUENELL                            1.0
# FIRANGI                            1.0
#
# [2484 rows x 1 columns]

# %% [markdown]
# ## Q 4. Next we study the main categories of the products.
#
# ## a) Create an appropriate plot to show the count of items ordered for each product_main_category. (6 marks).
#
# ### Hint: Create a bar chart titled "Product Category type" where product_main_category are on x-axis and counts are on y-axis.
#
# ### Note: Both axis labels, i.e. the names of the product_main_category and counts must be clearly legible.
#
# ## b) From the plot identify for which two product_main_category(s)  maximum and minimum orders were placed. (2 marks)
#
# ## c) Write code to print out the top 5 product_main_category(s)  in descending order? (3 marks

# %% [markdown]
# ### Ans 4 a)

# %%
## Here is the code to get plot of count of orders placed for product main category

plt.figure(figsize=(15,7))
sns.countplot(x="product_main_category",data=ECom_Data,order=ECom_Data["product_main_category"].value_counts().index)
plt.xlabel("Product Main Category",fontsize=12)
plt.ylabel("Counts", fontsize=12)
plt.title("Product Category type",fontsize=15)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Ans 4 b)

# %% [markdown]
# #### From the above plot we can clearly see that Clothing has the most numbers of orders followed by Mobiles and Accessories and Wearable Smart Devices has the least number of orders followed by Food and Nutrition

# %% [markdown]
# ### Ans 4 c)

# %%
## Code to print top five product main category is as follows: 

ECom_Data["product_main_category"].value_counts().head()
# Out:
# product_main_category
# Clothing                       2943
# Mobiles & Accessories          1084
# Automotive                     1001
# Home Decor & Festive Needs      727
# Computers                       558
# Name: count, dtype: int64

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#     In E-commerce, both the retailers (here brands) and the company have to make profit to sustain in the business.
#     The E-Commerce company has the following rule for computing their own revenue: </font>
#
# ####     The company charges
# ####  (i) 25% on the orders having final price (discounted price) greater than 600
#
# #### (ii) 15% on the orders having final price (discounted price) greater than 350 but less than or equal to 600
#
# #### (iii) 10% on the orders having final price (discounted price) greater than 100 but less than or equal to 350
#
# #### (iv) Otherwise, 5% on the final price (discounted price)    </font>

# %% [markdown]
# ## Q 5. Find the Total Revenue generated by the E-Commerce company over all orders placed. (6 marks)
#
# #### Hint: Calculate revenue of E-commerce company using the conditions mentioned above and then do the total (sum) of all to get total Revenue.

# %% [markdown]
# ### Ans 5

# %%
### Using for loop to generate a revenue column by iterating each value of discounted price and checking condition
### given in the loop(as instructed above)

for i,value in enumerate(ECom_Data["discounted_price"]):
    if value>600:
        ECom_Data.loc[i,"revenue"]=value*0.25
    elif value<=600 and value>350:
        ECom_Data.loc[i,"revenue"]=value*0.15
    elif value<=350 and value>100:
        ECom_Data.loc[i,"revenue"]=value*0.1
    else:
        ECom_Data.loc[i,"revenue"]=value*0.05

# %%
ECom_Data.head()
# Out:
#                    Customer_uniq_id Region  Order_Date Expected_Delivery_Date
# 0  e71017e224688489edfe856f2308806d  East   24-10-2021             25-10-2021  \
# 1  6286847ee2da18f587503db49511c539  East   24-10-2021             25-10-2021
# 2  0686fec9b70e5039583a38119ca0c835   West  24-10-2021             25-10-2021
# 3  ea2406dc597bee2abb6b867fa668501f   West  24-10-2021             25-10-2021
# 4  5935ed077915347dc695744df68c565c  East   03-09-2021             04-09-2021
#
#   Delivered_Date                                       product_name
# 0     25-10-2021  Indcrown Net Embroidered Semi-stitched Lehenga...  \
# 1     25-10-2021      Shopmania Music Band A5 Notebook Spiral Bound
# 2     25-10-2021      Shopmania Music Band A5 Notebook Spiral Bound
# 3     25-10-2021  Tiara Diaries 2016-2017 Designer LA Kaarta "TA...
# 4     04-09-2021                KAJCI Embroidered Women's Waistcoat
#
#   product_main_category    product_subcategory product_category_filter
# ...

# %%
ECom_Data["revenue"].sum()
# Out:
# 2217486.85

# %% [markdown]
# #### Hence total revenue generated by Ecom company is 2217486.85.

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#     Now you need to find the revenue for each retailer (Brand)
#     </font>

# %% [markdown]
# ## Q6.Calculate the total BrandRevenue and list the top 10 Brand having maximum revenue in descending order (6 marks)
# #### Hint: Total BrandRevenue is BrandRevenue which is generated after all the deductions. Also, BrandRevenue is different from the E-Commerce company's revenue.
# #### Brand Revenue is the discounted price minus the Revenue (generated using the conditions given above Q5)

# %% [markdown]
# ### Ans 6

# %%
### Adding a column "BrandRevenue" in given dataset by subtracting revenue from discounted price

ECom_Data["BrandRevenue"]=ECom_Data["discounted_price"]-ECom_Data["revenue"]

# %%
ECom_Data.head()
# Out:
#                    Customer_uniq_id Region  Order_Date Expected_Delivery_Date
# 0  e71017e224688489edfe856f2308806d  East   24-10-2021             25-10-2021  \
# 1  6286847ee2da18f587503db49511c539  East   24-10-2021             25-10-2021
# 2  0686fec9b70e5039583a38119ca0c835   West  24-10-2021             25-10-2021
# 3  ea2406dc597bee2abb6b867fa668501f   West  24-10-2021             25-10-2021
# 4  5935ed077915347dc695744df68c565c  East   03-09-2021             04-09-2021
#
#   Delivered_Date                                       product_name
# 0     25-10-2021  Indcrown Net Embroidered Semi-stitched Lehenga...  \
# 1     25-10-2021      Shopmania Music Band A5 Notebook Spiral Bound
# 2     25-10-2021      Shopmania Music Band A5 Notebook Spiral Bound
# 3     25-10-2021  Tiara Diaries 2016-2017 Designer LA Kaarta "TA...
# 4     04-09-2021                KAJCI Embroidered Women's Waistcoat
#
#   product_main_category    product_subcategory product_category_filter
# ...

# %%
ECom_Data["BrandRevenue"].sum()
# Out:
# 7522992.15

# %% [markdown]
# #### As is clear in above code Total brand revenue is 7522992.15

# %%
ECom_Data.groupby(["Brand"])["BrandRevenue"].sum().sort_values(ascending=False).head(10)
# Out:
# Brand
# ALLURE AUTO     498464.25
# GAGA            237390.00
# SLIM            212062.60
# DAILYOBJECTS    181980.00
# DIVINITI        143115.00
# THELOSTPUPPY    127287.50
# REGULAR         126536.50
# ENTHOPIA        123146.25
# ASUS             99241.50
# SPRINGWEL        88978.50
# Name: BrandRevenue, dtype: float64

# %% [markdown]
# #### Top 10 Brands which are generating maximum BrandRevenue are as follows :
# 1. ALLURE AUTO 2.GAGA 3. SLIM 4. DAILYOBJECTS 5.DIVINITI 6.THELOSTPUPPY 7.REGULAR 8.ENTHOPIA 9.ASUS 10.SPRINGWEL

# %%
ECom_Data.groupby(["Brand"])["revenue"].sum().sort_values(ascending=False).head(10)
# Out:
# Brand
# ALLURE AUTO     166154.75
# GAGA             79130.00
# DAILYOBJECTS     60660.00
# SLIM             60114.40
# DIVINITI         47705.00
# ENTHOPIA         41048.75
# ASUS             33080.50
# SPRINGWEL        29659.50
# AUDEZE           29073.00
# REGULAR          26442.50
# Name: revenue, dtype: float64

# %% [markdown]
# #### Top 10 brand which are generating maximum revenue for ECom Company are as follows:
# 1.ALLURE AUTO 2.GAGA 3.DAILYOBJECTS 4.SLIM 5.DIVINITI 6.ENTHOPIA 7.ASUS 8.SPRINGWEL 9.AUDEZE 10.REGULAR

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
# Let us now investigate multiple features for each product to determine any pattern.
# </font>

# %% [markdown]
# ## Q 7. Compare prices for each product.
#
# ## a)	Draw boxplots of retail_price & discounted_price. (3 marks)
#
# ## b)	 Are there any outliers? (Yes/No) (1mark)
#
# ## c)	Create a scatterplot of retail_price (x-axis) and discounted_price (y-axis) (3 marks)

# %% [markdown]
# ### Ans 7 a)

# %%
for i in ECom_Data[["retail_price","discounted_price"]]:
    plt.figure(figsize=(20,7))
    sns.boxplot(data=ECom_Data,x=i)

# %% [markdown]
# ### Ans 7 b)

# %% [markdown]
# #### From boxplot plotted above we can say that we have outliers for both retail price and discounted price.

# %% [markdown]
# ### Ans 7 c)

# %%
plt.figure(figsize=(15,7))
sns.scatterplot(x="retail_price",y="discounted_price",data=ECom_Data)
plt.title("Scatterplot of Retail_Price and Discounted_Price",fontsize=15)
plt.xlabel("Retail_Price",fontsize=13)
plt.ylabel("Discounted_Price",fontsize=13)
plt.show()

# %% [markdown]
# #### From the above plot we can conclude that retail_price and discounted_price are positively correlated and there are outliers clearly visible

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#     The next steps will enable to study brand-level information.
#     </font>

# %% [markdown]
# ## Q 8. Create a new dataframe to include the Brand specific information as stated:
# ## i.	total number of orders placed per Brand
# ## ii.	total retail_price per Brand
# ## iii.	total discounted_price per Brand, and
# ## iv.	total BrandRevenue generated per Brand.
#
# ## Also, draw a pairplot using these four features. (6 marks)

# %% [markdown]
# ### Ans 8

# %%
## Creating a new dataframe of name Brand_Info 

Brand_Info=pd.DataFrame({"Total_Order_Placed":ECom_Data.groupby(["Brand"])["Brand"].count().values,
                        
                         "Total_Retail_Price":ECom_Data.groupby(["Brand"])["retail_price"].sum().values,
                        
                         "Total_Discounted_Price":ECom_Data.groupby(["Brand"])["discounted_price"].sum().values,
                        
                         "Total_BrandRevenue":ECom_Data.groupby(["Brand"])["BrandRevenue"].sum().values},
                       
                        index=ECom_Data.groupby(["Brand"])["Brand"].count().index)

# %%
Brand_Info.reset_index("Brand",inplace=True)

# %%
Brand_Info.head()
# Out:
#          Brand  Total_Order_Placed  Total_Retail_Price
# 0         1OAK                   2                1698  \
# 1  3A AUTOCARE                  41              107059
# 2       3D MAT                   1                7250
# 3    3KFACTORY                   1                 399
# 4           4D                   5               17500
#
#    Total_Discounted_Price  Total_BrandRevenue
# 0                    1274             1015.40
# 1                   74134            55647.90
# 2                    6999             5249.25
# 3                     174              156.60
# 4                    7948             5961.00

# %%
sns.pairplot(Brand_Info[["Total_Order_Placed","Total_Retail_Price","Total_Discounted_Price","Total_BrandRevenue"]])

# %% [markdown]
# #### Some inference to be drawn from the pairplot are:
# ##### 1.Total Retail Price and Total Discounted Price have positive correlation.
# ##### 2.Total Retail Price and Total BrandRevenue have positive correlation.
# ##### 3.Total Discounted Price and Total BrandRevenue has positive relation.
# ##### 4.Most of the orders are less than 100 in number.

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#     The E-Commerce company operate in multiple regions. It is important to understand its performance in each region.
#     </font>

# %% [markdown]
# ## Q 9.Compare performance regionwise
#
# ## a)	Draw a lineplot for the monthly Revenue of E-Commerce Company for each region separately.  (4 marks)
#
# ## b)	Identify the best and the worst performing months for each region. (2 marks)
#
# #### Note: Only those days with actual orders(Order_Date) placed are present in the dataset. Assuming there were no orders on other days. Also, show Month and Year on x-axis.

# %% [markdown]
# ### Ans 9 a)

# %%
## To solve this questions our first task is to extract month from Order_Date which have been done below

ECom_Data["Month"]=pd.to_datetime(ECom_Data["Order_Date"],dayfirst=True).dt.month
ECom_Data.head()
# Out:
#                    Customer_uniq_id Region  Order_Date Expected_Delivery_Date
# 0  e71017e224688489edfe856f2308806d  East   24-10-2021             25-10-2021  \
# 1  6286847ee2da18f587503db49511c539  East   24-10-2021             25-10-2021
# 2  0686fec9b70e5039583a38119ca0c835   West  24-10-2021             25-10-2021
# 3  ea2406dc597bee2abb6b867fa668501f   West  24-10-2021             25-10-2021
# 4  5935ed077915347dc695744df68c565c  East   03-09-2021             04-09-2021
#
#   Delivered_Date                                       product_name
# 0     25-10-2021  Indcrown Net Embroidered Semi-stitched Lehenga...  \
# 1     25-10-2021      Shopmania Music Band A5 Notebook Spiral Bound
# 2     25-10-2021      Shopmania Music Band A5 Notebook Spiral Bound
# 3     25-10-2021  Tiara Diaries 2016-2017 Designer LA Kaarta "TA...
# 4     04-09-2021                KAJCI Embroidered Women's Waistcoat
#
#   product_main_category    product_subcategory product_category_filter
# ...

# %%
## Now plotting total revenue generated in respect of each month

plt.figure(figsize=(15,7))
sns.lineplot(x="Month",y="revenue",data=ECom_Data,marker="*",markersize=12,estimator=np.sum,hue="Region",errorbar=None)
plt.xticks(np.arange(1,13))
plt.title("Month wise Revenue for Different Region")
plt.ylabel("Total revenue generated")
plt.show()

# %%
plt.figure(figsize=(15,7))
data=ECom_Data[ECom_Data["Region"]=="West"]
sns.lineplot(data=data,x="Month",y="revenue",errorbar=None,estimator=np.sum,marker="*",markersize=12)
plt.xticks(np.arange(1,13))
plt.title("Monthwise Revenue for West Region")
plt.ylabel("Total revenue generated")
plt.show()

# %%
plt.figure(figsize=(15,7))
data=ECom_Data[ECom_Data["Region"]=="East "]
sns.lineplot(data=data,x="Month",y="revenue",errorbar=None,estimator=np.sum,marker="*",markersize=12)
plt.xticks(np.arange(1,13))
plt.title("Monthwise Revenue for East Region")
plt.ylabel("Total revenue generated")
plt.show()

# %%
plt.figure(figsize=(15,7))
data=ECom_Data[ECom_Data["Region"]=="South"]
sns.lineplot(data=data,x="Month",y="revenue",errorbar=None,estimator=np.sum,marker="*",markersize=12)
plt.xticks(np.arange(1,13))
plt.title("Monthwise Revenue for South Region")
plt.ylabel("Total revenue generated")
plt.show()

# %%
plt.figure(figsize=(15,7))
data=ECom_Data[ECom_Data["Region"]=="North"]
sns.lineplot(data=data,x="Month",y="revenue",errorbar=None,estimator=np.sum,marker="*",markersize=12)
plt.xticks(np.arange(1,13))
plt.title("Monthwise Revenue for North Region")
plt.ylabel("Total revenue generated")
plt.show()

# %% [markdown]
# ### Ans 9 b)

# %% [markdown]
# #### Based on the above plotted graphs, here are inferences
# #### 1. December is the best and October is the worst performing month for West region
# #### 2. December is the best and October is the worst performing month for East region
# #### 3. December is the best and May is the worst performing month for South region
# #### 4. December is the best and July is the worst performing month for North region
# #### 5. East  is the most profitable region and South is the least profitable region
# #### 6. In all regions December is the best performing month and October is the worst performing month

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#     Congratulations! You have learnt how to approach a complex data and extract information out of it.
#     </font>
